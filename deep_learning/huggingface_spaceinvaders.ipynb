# %% [markdown]
# # Unit 3: Deep Q-Learning with Atari Games 👾 using RL Baselines3 Zoo
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit4/thumbnail.jpg" alt="Unit 3 Thumbnail">
#
# In this notebook, **you'll train a Deep Q-Learning agent** playing Space Invaders using [RL Baselines3 Zoo](https://github.com/DLR-RM/rl-baselines3-zoo), a training framework based on [Stable-Baselines3](https://stable-baselines3.readthedocs.io/en/master/) that provides scripts for training, evaluating agents, tuning hyperparameters, plotting results and recording videos.
#
# We're using the [RL-Baselines-3 Zoo integration, a vanilla version of Deep Q-Learning](https://stable-baselines3.readthedocs.io/en/master/modules/dqn.html) with no extensions such as Double-DQN, Dueling-DQN, and Prioritized Experience Replay.
#
# ⬇️ Here is an example of what **you will achieve** ⬇️

# %% [markdown]
# # Let's train a Deep Q-Learning agent playing Atari' Space Invaders 👾 and upload it to the Hub.
#
# We strongly recommend students **to use Google Colab for the hands-on exercises instead of running them on their personal computers**.
#
# By using Google Colab, **you can focus on learning and experimenting without worrying about the technical aspects of setting up your environments**.
#
# To validate this hands-on for the certification process, you need to push your trained model to the Hub and **get a result of >= 200**.
#
# To find your result, go to the leaderboard and find your model, **the result = mean_reward - std of reward**
#
# For more information about the certification process, check this section 👉 https://huggingface.co/deep-rl-course/en/unit0/introduction#certification-process

# %%
# !pip install git+https://github.com/DLR-RM/rl-baselines3-zoo

# %%
# !apt-get install swig cmake ffmpeg

# %%
# !pip install gymnasium[atari]
# !pip install gymnasium[accept-rom-license]

# %% [markdown]
# ## Create a virtual display 🔽

# %%
# %%capture
# !apt install python-opengl
# !apt install xvfb
# !pip3 install pyvirtualdisplay

# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %% [markdown]
# ## Train our Deep Q-Learning Agent to Play Space Invaders 👾
#
# To train an agent with RL-Baselines3-Zoo, we just need to do two things:
#
# 1. Create a hyperparameter config file that will contain our training hyperparameters called `dqn.yml`.

# %%
# !python -m rl_zoo3.train --algo dqn  --env SpaceInvadersNoFrameskip-v4 -f logs/ -c dqn.yml
# Out:
# Streaming output truncated to the last 5000 lines.
# |    ep_rew_mean      | 401      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2636     |
# |    fps              | 264      |
# |    time_elapsed     | 2068     |
# |    total_timesteps  | 546767   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0321   |
# |    n_updates        | 111691   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.2e+03  |
# |    ep_rew_mean      | 401      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2640     |
# |    fps              | 264      |
# |    time_elapsed     | 2071     |
# |    total_timesteps  | 547474   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0305   |
# |    n_updates        | 111868   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.19e+03 |
# |    ep_rew_mean      | 398      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2644     |
# |    fps              | 264      |
# |    time_elapsed     | 2075     |
# |    total_timesteps  | 548367   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0328   |
# |    n_updates        | 112091   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.19e+03 |
# |    ep_rew_mean      | 396      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2648     |
# |    fps              | 264      |
# |    time_elapsed     | 2080     |
# |    total_timesteps  | 549832   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0388   |
# |    n_updates        | 112457   |
# ----------------------------------
# Eval num_timesteps=550000, episode_reward=399.00 +/- 165.18
# Episode length: 3038.40 +/- 990.97
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.04e+03 |
# |    mean_reward      | 399      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 550000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0106   |
# |    n_updates        | 112499   |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.2e+03  |
# |    ep_rew_mean      | 398      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2652     |
# |    fps              | 263      |
# |    time_elapsed     | 2092     |
# |    total_timesteps  | 550670   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0176   |
# |    n_updates        | 112667   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.17e+03 |
# |    ep_rew_mean      | 394      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2656     |
# |    fps              | 263      |
# |    time_elapsed     | 2097     |
# |    total_timesteps  | 551952   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0382   |
# |    n_updates        | 112987   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.16e+03 |
# |    ep_rew_mean      | 395      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2660     |
# |    fps              | 263      |
# |    time_elapsed     | 2100     |
# |    total_timesteps  | 552564   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0134   |
# |    n_updates        | 113140   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.16e+03 |
# |    ep_rew_mean      | 396      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2664     |
# |    fps              | 263      |
# |    time_elapsed     | 2102     |
# |    total_timesteps  | 553160   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0121   |
# |    n_updates        | 113289   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.14e+03 |
# |    ep_rew_mean      | 392      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2668     |
# |    fps              | 263      |
# |    time_elapsed     | 2104     |
# |    total_timesteps  | 553625   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0225   |
# |    n_updates        | 113406   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.13e+03 |
# |    ep_rew_mean      | 393      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2672     |
# |    fps              | 263      |
# |    time_elapsed     | 2107     |
# |    total_timesteps  | 554432   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0183   |
# |    n_updates        | 113607   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.11e+03 |
# |    ep_rew_mean      | 388      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2676     |
# |    fps              | 263      |
# |    time_elapsed     | 2111     |
# |    total_timesteps  | 555551   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0176   |
# |    n_updates        | 113887   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.11e+03 |
# |    ep_rew_mean      | 386      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2680     |
# |    fps              | 263      |
# |    time_elapsed     | 2115     |
# |    total_timesteps  | 556419   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0278   |
# |    n_updates        | 114104   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.12e+03 |
# |    ep_rew_mean      | 388      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2684     |
# |    fps              | 263      |
# |    time_elapsed     | 2119     |
# |    total_timesteps  | 557667   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0342   |
# |    n_updates        | 114416   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.14e+03 |
# |    ep_rew_mean      | 391      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2688     |
# |    fps              | 263      |
# |    time_elapsed     | 2125     |
# |    total_timesteps  | 559218   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0236   |
# |    n_updates        | 114804   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.13e+03 |
# |    ep_rew_mean      | 392      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2692     |
# |    fps              | 263      |
# |    time_elapsed     | 2129     |
# |    total_timesteps  | 560086   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.027    |
# |    n_updates        | 115021   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.1e+03  |
# |    ep_rew_mean      | 384      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2696     |
# |    fps              | 263      |
# |    time_elapsed     | 2132     |
# |    total_timesteps  | 560905   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0322   |
# |    n_updates        | 115226   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.09e+03 |
# |    ep_rew_mean      | 384      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2700     |
# |    fps              | 263      |
# |    time_elapsed     | 2135     |
# |    total_timesteps  | 561716   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0534   |
# |    n_updates        | 115428   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.07e+03 |
# |    ep_rew_mean      | 379      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2704     |
# |    fps              | 263      |
# |    time_elapsed     | 2140     |
# |    total_timesteps  | 562963   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0158   |
# |    n_updates        | 115740   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.09e+03 |
# |    ep_rew_mean      | 382      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2708     |
# |    fps              | 263      |
# |    time_elapsed     | 2143     |
# |    total_timesteps  | 563730   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0191   |
# |    n_updates        | 115932   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.07e+03 |
# |    ep_rew_mean      | 382      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2712     |
# |    fps              | 263      |
# |    time_elapsed     | 2146     |
# |    total_timesteps  | 564564   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0116   |
# |    n_updates        | 116140   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.07e+03 |
# |    ep_rew_mean      | 382      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2716     |
# |    fps              | 263      |
# |    time_elapsed     | 2149     |
# |    total_timesteps  | 565429   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0228   |
# |    n_updates        | 116357   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.09e+03 |
# |    ep_rew_mean      | 384      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2720     |
# |    fps              | 263      |
# |    time_elapsed     | 2153     |
# |    total_timesteps  | 566336   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0112   |
# |    n_updates        | 116583   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.08e+03 |
# |    ep_rew_mean      | 383      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2724     |
# |    fps              | 262      |
# |    time_elapsed     | 2157     |
# |    total_timesteps  | 567438   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0194   |
# |    n_updates        | 116859   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.09e+03 |
# |    ep_rew_mean      | 383      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2728     |
# |    fps              | 263      |
# |    time_elapsed     | 2162     |
# |    total_timesteps  | 568674   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0549   |
# |    n_updates        | 117168   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.06e+03 |
# |    ep_rew_mean      | 377      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2732     |
# |    fps              | 263      |
# |    time_elapsed     | 2164     |
# |    total_timesteps  | 569287   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0124   |
# |    n_updates        | 117321   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.05e+03 |
# |    ep_rew_mean      | 374      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2736     |
# |    fps              | 262      |
# |    time_elapsed     | 2169     |
# |    total_timesteps  | 570627   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.023    |
# |    n_updates        | 117656   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.06e+03 |
# |    ep_rew_mean      | 374      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2740     |
# |    fps              | 262      |
# |    time_elapsed     | 2172     |
# |    total_timesteps  | 571428   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0402   |
# |    n_updates        | 117856   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.08e+03 |
# |    ep_rew_mean      | 378      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2744     |
# |    fps              | 263      |
# |    time_elapsed     | 2178     |
# |    total_timesteps  | 573063   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.023    |
# |    n_updates        | 118265   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.1e+03  |
# |    ep_rew_mean      | 385      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2748     |
# |    fps              | 262      |
# |    time_elapsed     | 2183     |
# |    total_timesteps  | 574271   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0249   |
# |    n_updates        | 118567   |
# ----------------------------------
# Eval num_timesteps=575000, episode_reward=201.00 +/- 112.31
# Episode length: 2530.20 +/- 945.66
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.53e+03 |
# |    mean_reward      | 201      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 575000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0196   |
# |    n_updates        | 118749   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.11e+03 |
# |    ep_rew_mean      | 386      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2752     |
# |    fps              | 262      |
# |    time_elapsed     | 2195     |
# |    total_timesteps  | 575421   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0463   |
# |    n_updates        | 118855   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.09e+03 |
# |    ep_rew_mean      | 385      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2756     |
# |    fps              | 262      |
# |    time_elapsed     | 2199     |
# |    total_timesteps  | 576372   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0275   |
# |    n_updates        | 119092   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.09e+03 |
# |    ep_rew_mean      | 385      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2760     |
# |    fps              | 262      |
# |    time_elapsed     | 2202     |
# |    total_timesteps  | 577310   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00855  |
# |    n_updates        | 119327   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.08e+03 |
# |    ep_rew_mean      | 382      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2764     |
# |    fps              | 262      |
# |    time_elapsed     | 2207     |
# |    total_timesteps  | 578552   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0189   |
# |    n_updates        | 119637   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.08e+03 |
# |    ep_rew_mean      | 380      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2768     |
# |    fps              | 262      |
# |    time_elapsed     | 2212     |
# |    total_timesteps  | 579845   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0538   |
# |    n_updates        | 119961   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.11e+03 |
# |    ep_rew_mean      | 385      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2772     |
# |    fps              | 262      |
# |    time_elapsed     | 2216     |
# |    total_timesteps  | 580954   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0128   |
# |    n_updates        | 120238   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.09e+03 |
# |    ep_rew_mean      | 381      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2776     |
# |    fps              | 262      |
# |    time_elapsed     | 2221     |
# |    total_timesteps  | 581995   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0213   |
# |    n_updates        | 120498   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.1e+03  |
# |    ep_rew_mean      | 381      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2780     |
# |    fps              | 262      |
# |    time_elapsed     | 2227     |
# |    total_timesteps  | 583746   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0215   |
# |    n_updates        | 120936   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.09e+03 |
# |    ep_rew_mean      | 379      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2784     |
# |    fps              | 262      |
# |    time_elapsed     | 2230     |
# |    total_timesteps  | 584639   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0193   |
# |    n_updates        | 121159   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.07e+03 |
# |    ep_rew_mean      | 377      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2788     |
# |    fps              | 262      |
# |    time_elapsed     | 2233     |
# |    total_timesteps  | 585295   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0196   |
# |    n_updates        | 121323   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.07e+03 |
# |    ep_rew_mean      | 377      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2792     |
# |    fps              | 262      |
# |    time_elapsed     | 2238     |
# |    total_timesteps  | 586598   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0634   |
# |    n_updates        | 121649   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.08e+03 |
# |    ep_rew_mean      | 382      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2796     |
# |    fps              | 262      |
# |    time_elapsed     | 2243     |
# |    total_timesteps  | 588007   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00689  |
# |    n_updates        | 122001   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.09e+03 |
# |    ep_rew_mean      | 381      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2800     |
# |    fps              | 262      |
# |    time_elapsed     | 2250     |
# |    total_timesteps  | 589860   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0229   |
# |    n_updates        | 122464   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.11e+03 |
# |    ep_rew_mean      | 387      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2804     |
# |    fps              | 262      |
# |    time_elapsed     | 2255     |
# |    total_timesteps  | 591080   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.034    |
# |    n_updates        | 122769   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.1e+03  |
# |    ep_rew_mean      | 386      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2808     |
# |    fps              | 262      |
# |    time_elapsed     | 2259     |
# |    total_timesteps  | 592129   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0473   |
# |    n_updates        | 123032   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.11e+03 |
# |    ep_rew_mean      | 387      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2812     |
# |    fps              | 262      |
# |    time_elapsed     | 2262     |
# |    total_timesteps  | 593008   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0207   |
# |    n_updates        | 123251   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.11e+03 |
# |    ep_rew_mean      | 386      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2816     |
# |    fps              | 262      |
# |    time_elapsed     | 2267     |
# |    total_timesteps  | 594280   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0747   |
# |    n_updates        | 123569   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.13e+03 |
# |    ep_rew_mean      | 387      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2820     |
# |    fps              | 262      |
# |    time_elapsed     | 2271     |
# |    total_timesteps  | 595261   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0226   |
# |    n_updates        | 123815   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.09e+03 |
# |    ep_rew_mean      | 384      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2824     |
# |    fps              | 262      |
# |    time_elapsed     | 2274     |
# |    total_timesteps  | 596064   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0435   |
# |    n_updates        | 124015   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.09e+03 |
# |    ep_rew_mean      | 383      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2828     |
# |    fps              | 262      |
# |    time_elapsed     | 2279     |
# |    total_timesteps  | 597250   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0184   |
# |    n_updates        | 124312   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.12e+03 |
# |    ep_rew_mean      | 387      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2832     |
# |    fps              | 262      |
# |    time_elapsed     | 2284     |
# |    total_timesteps  | 598645   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0491   |
# |    n_updates        | 124661   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.14e+03 |
# |    ep_rew_mean      | 390      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2836     |
# |    fps              | 262      |
# |    time_elapsed     | 2289     |
# |    total_timesteps  | 599779   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0198   |
# |    n_updates        | 124944   |
# ----------------------------------
# Eval num_timesteps=600000, episode_reward=209.00 +/- 92.60
# Episode length: 2954.20 +/- 456.78
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.95e+03 |
# |    mean_reward      | 209      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 600000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0277   |
# |    n_updates        | 124999   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.15e+03 |
# |    ep_rew_mean      | 393      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2840     |
# |    fps              | 261      |
# |    time_elapsed     | 2302     |
# |    total_timesteps  | 601039   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0479   |
# |    n_updates        | 125259   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.15e+03 |
# |    ep_rew_mean      | 394      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2844     |
# |    fps              | 261      |
# |    time_elapsed     | 2307     |
# |    total_timesteps  | 602669   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0217   |
# |    n_updates        | 125667   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.17e+03 |
# |    ep_rew_mean      | 395      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2848     |
# |    fps              | 261      |
# |    time_elapsed     | 2312     |
# |    total_timesteps  | 603892   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0181   |
# |    n_updates        | 125972   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.15e+03 |
# |    ep_rew_mean      | 395      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2852     |
# |    fps              | 261      |
# |    time_elapsed     | 2317     |
# |    total_timesteps  | 605152   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0233   |
# |    n_updates        | 126287   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.16e+03 |
# |    ep_rew_mean      | 398      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2856     |
# |    fps              | 261      |
# |    time_elapsed     | 2321     |
# |    total_timesteps  | 606214   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0277   |
# |    n_updates        | 126553   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.17e+03 |
# |    ep_rew_mean      | 397      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2860     |
# |    fps              | 261      |
# |    time_elapsed     | 2326     |
# |    total_timesteps  | 607579   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0104   |
# |    n_updates        | 126894   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.16e+03 |
# |    ep_rew_mean      | 397      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2864     |
# |    fps              | 261      |
# |    time_elapsed     | 2331     |
# |    total_timesteps  | 608823   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0136   |
# |    n_updates        | 127205   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.15e+03 |
# |    ep_rew_mean      | 393      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2868     |
# |    fps              | 261      |
# |    time_elapsed     | 2334     |
# |    total_timesteps  | 609739   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0191   |
# |    n_updates        | 127434   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.15e+03 |
# |    ep_rew_mean      | 394      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2872     |
# |    fps              | 261      |
# |    time_elapsed     | 2340     |
# |    total_timesteps  | 611177   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0308   |
# |    n_updates        | 127794   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.15e+03 |
# |    ep_rew_mean      | 396      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2876     |
# |    fps              | 261      |
# |    time_elapsed     | 2344     |
# |    total_timesteps  | 612182   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0461   |
# |    n_updates        | 128045   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.17e+03 |
# |    ep_rew_mean      | 400      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2880     |
# |    fps              | 261      |
# |    time_elapsed     | 2349     |
# |    total_timesteps  | 613582   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0358   |
# |    n_updates        | 128395   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.15e+03 |
# |    ep_rew_mean      | 397      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2884     |
# |    fps              | 261      |
# |    time_elapsed     | 2352     |
# |    total_timesteps  | 614371   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0238   |
# |    n_updates        | 128592   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.15e+03 |
# |    ep_rew_mean      | 398      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2888     |
# |    fps              | 261      |
# |    time_elapsed     | 2356     |
# |    total_timesteps  | 615238   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0265   |
# |    n_updates        | 128809   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.17e+03 |
# |    ep_rew_mean      | 401      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2892     |
# |    fps              | 261      |
# |    time_elapsed     | 2360     |
# |    total_timesteps  | 616537   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0126   |
# |    n_updates        | 129134   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.15e+03 |
# |    ep_rew_mean      | 397      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2896     |
# |    fps              | 261      |
# |    time_elapsed     | 2363     |
# |    total_timesteps  | 617240   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0506   |
# |    n_updates        | 129309   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.15e+03 |
# |    ep_rew_mean      | 400      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2900     |
# |    fps              | 261      |
# |    time_elapsed     | 2368     |
# |    total_timesteps  | 618551   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0129   |
# |    n_updates        | 129637   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.17e+03 |
# |    ep_rew_mean      | 404      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2904     |
# |    fps              | 261      |
# |    time_elapsed     | 2374     |
# |    total_timesteps  | 620076   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0158   |
# |    n_updates        | 130018   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.18e+03 |
# |    ep_rew_mean      | 406      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2908     |
# |    fps              | 261      |
# |    time_elapsed     | 2381     |
# |    total_timesteps  | 621807   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0148   |
# |    n_updates        | 130451   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.19e+03 |
# |    ep_rew_mean      | 409      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2912     |
# |    fps              | 261      |
# |    time_elapsed     | 2384     |
# |    total_timesteps  | 622762   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0429   |
# |    n_updates        | 130690   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.22e+03 |
# |    ep_rew_mean      | 414      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2916     |
# |    fps              | 261      |
# |    time_elapsed     | 2388     |
# |    total_timesteps  | 623853   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0269   |
# |    n_updates        | 130963   |
# ----------------------------------
# Eval num_timesteps=625000, episode_reward=500.00 +/- 102.57
# Episode length: 3554.80 +/- 980.40
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.55e+03 |
# |    mean_reward      | 500      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 625000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0256   |
# |    n_updates        | 131249   |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.21e+03 |
# |    ep_rew_mean      | 411      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2920     |
# |    fps              | 260      |
# |    time_elapsed     | 2403     |
# |    total_timesteps  | 625058   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0383   |
# |    n_updates        | 131264   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.22e+03 |
# |    ep_rew_mean      | 412      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2924     |
# |    fps              | 260      |
# |    time_elapsed     | 2408     |
# |    total_timesteps  | 626463   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0294   |
# |    n_updates        | 131615   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.25e+03 |
# |    ep_rew_mean      | 417      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2928     |
# |    fps              | 260      |
# |    time_elapsed     | 2415     |
# |    total_timesteps  | 628434   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0607   |
# |    n_updates        | 132108   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.31e+03 |
# |    ep_rew_mean      | 422      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2932     |
# |    fps              | 260      |
# |    time_elapsed     | 2422     |
# |    total_timesteps  | 630091   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0162   |
# |    n_updates        | 132522   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.33e+03 |
# |    ep_rew_mean      | 426      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2936     |
# |    fps              | 260      |
# |    time_elapsed     | 2427     |
# |    total_timesteps  | 631533   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0437   |
# |    n_updates        | 132883   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.32e+03 |
# |    ep_rew_mean      | 423      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2940     |
# |    fps              | 260      |
# |    time_elapsed     | 2433     |
# |    total_timesteps  | 632939   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0435   |
# |    n_updates        | 133234   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.34e+03 |
# |    ep_rew_mean      | 423      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2944     |
# |    fps              | 260      |
# |    time_elapsed     | 2436     |
# |    total_timesteps  | 633673   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0353   |
# |    n_updates        | 133418   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.36e+03 |
# |    ep_rew_mean      | 426      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2948     |
# |    fps              | 260      |
# |    time_elapsed     | 2441     |
# |    total_timesteps  | 635137   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0341   |
# |    n_updates        | 133784   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.37e+03 |
# |    ep_rew_mean      | 429      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2952     |
# |    fps              | 260      |
# |    time_elapsed     | 2445     |
# |    total_timesteps  | 636206   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0275   |
# |    n_updates        | 134051   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.39e+03 |
# |    ep_rew_mean      | 430      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2956     |
# |    fps              | 260      |
# |    time_elapsed     | 2449     |
# |    total_timesteps  | 637076   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0297   |
# |    n_updates        | 134268   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.4e+03  |
# |    ep_rew_mean      | 432      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2960     |
# |    fps              | 260      |
# |    time_elapsed     | 2457     |
# |    total_timesteps  | 639192   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0165   |
# |    n_updates        | 134797   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.46e+03 |
# |    ep_rew_mean      | 443      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2964     |
# |    fps              | 260      |
# |    time_elapsed     | 2461     |
# |    total_timesteps  | 640241   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0338   |
# |    n_updates        | 135060   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.44e+03 |
# |    ep_rew_mean      | 441      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2968     |
# |    fps              | 260      |
# |    time_elapsed     | 2465     |
# |    total_timesteps  | 641307   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0259   |
# |    n_updates        | 135326   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.45e+03 |
# |    ep_rew_mean      | 442      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2972     |
# |    fps              | 260      |
# |    time_elapsed     | 2471     |
# |    total_timesteps  | 642880   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0834   |
# |    n_updates        | 135719   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.44e+03 |
# |    ep_rew_mean      | 449      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2976     |
# |    fps              | 260      |
# |    time_elapsed     | 2475     |
# |    total_timesteps  | 643719   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.024    |
# |    n_updates        | 135929   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.47e+03 |
# |    ep_rew_mean      | 451      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2980     |
# |    fps              | 260      |
# |    time_elapsed     | 2482     |
# |    total_timesteps  | 645710   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0139   |
# |    n_updates        | 136427   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.49e+03 |
# ...
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0174   |
# |    n_updates        | 212499   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.1e+03  |
# |    ep_rew_mean      | 590      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3780     |
# |    fps              | 249      |
# |    time_elapsed     | 3808     |
# |    total_timesteps  | 951530   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0107   |
# |    n_updates        | 212882   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.1e+03  |
# |    ep_rew_mean      | 596      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3784     |
# |    fps              | 249      |
# |    time_elapsed     | 3816     |
# |    total_timesteps  | 953313   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0178   |
# |    n_updates        | 213328   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.1e+03  |
# |    ep_rew_mean      | 597      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3788     |
# |    fps              | 249      |
# |    time_elapsed     | 3822     |
# |    total_timesteps  | 955132   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0268   |
# |    n_updates        | 213782   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.11e+03 |
# |    ep_rew_mean      | 597      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3792     |
# |    fps              | 249      |
# |    time_elapsed     | 3826     |
# |    total_timesteps  | 956096   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0202   |
# |    n_updates        | 214023   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.07e+03 |
# |    ep_rew_mean      | 595      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3796     |
# |    fps              | 249      |
# |    time_elapsed     | 3833     |
# |    total_timesteps  | 957928   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0333   |
# |    n_updates        | 214481   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.08e+03 |
# |    ep_rew_mean      | 596      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3800     |
# |    fps              | 249      |
# |    time_elapsed     | 3840     |
# |    total_timesteps  | 959546   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0198   |
# |    n_updates        | 214886   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.09e+03 |
# |    ep_rew_mean      | 596      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3804     |
# |    fps              | 249      |
# |    time_elapsed     | 3847     |
# |    total_timesteps  | 961711   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0168   |
# |    n_updates        | 215427   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.13e+03 |
# |    ep_rew_mean      | 602      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3808     |
# |    fps              | 249      |
# |    time_elapsed     | 3855     |
# |    total_timesteps  | 963764   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0264   |
# |    n_updates        | 215940   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.12e+03 |
# |    ep_rew_mean      | 599      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3812     |
# |    fps              | 249      |
# |    time_elapsed     | 3862     |
# |    total_timesteps  | 965527   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00893  |
# |    n_updates        | 216381   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.06e+03 |
# |    ep_rew_mean      | 599      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3816     |
# |    fps              | 250      |
# |    time_elapsed     | 3870     |
# |    total_timesteps  | 967580   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0136   |
# |    n_updates        | 216894   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.06e+03 |
# |    ep_rew_mean      | 601      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3820     |
# |    fps              | 250      |
# |    time_elapsed     | 3877     |
# |    total_timesteps  | 969478   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0583   |
# |    n_updates        | 217369   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.06e+03 |
# |    ep_rew_mean      | 595      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3824     |
# |    fps              | 250      |
# |    time_elapsed     | 3885     |
# |    total_timesteps  | 971574   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0125   |
# |    n_updates        | 217893   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.06e+03 |
# |    ep_rew_mean      | 595      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3828     |
# |    fps              | 250      |
# |    time_elapsed     | 3892     |
# |    total_timesteps  | 973376   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.028    |
# |    n_updates        | 218343   |
# ----------------------------------
# Eval num_timesteps=975000, episode_reward=528.00 +/- 126.95
# Episode length: 3597.80 +/- 1048.01
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.6e+03  |
# |    mean_reward      | 528      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 975000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00889  |
# |    n_updates        | 218749   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.02e+03 |
# |    ep_rew_mean      | 596      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3832     |
# |    fps              | 249      |
# |    time_elapsed     | 3909     |
# |    total_timesteps  | 975247   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.028    |
# |    n_updates        | 218811   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.02e+03 |
# |    ep_rew_mean      | 593      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3836     |
# |    fps              | 249      |
# |    time_elapsed     | 3918     |
# |    total_timesteps  | 977607   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0259   |
# |    n_updates        | 219401   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.03e+03 |
# |    ep_rew_mean      | 603      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3840     |
# |    fps              | 249      |
# |    time_elapsed     | 3925     |
# |    total_timesteps  | 979499   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0177   |
# |    n_updates        | 219874   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4e+03    |
# |    ep_rew_mean      | 599      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3844     |
# |    fps              | 249      |
# |    time_elapsed     | 3932     |
# |    total_timesteps  | 981173   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0129   |
# |    n_updates        | 220293   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.02e+03 |
# |    ep_rew_mean      | 601      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3848     |
# |    fps              | 249      |
# |    time_elapsed     | 3937     |
# |    total_timesteps  | 982700   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0167   |
# |    n_updates        | 220674   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.02e+03 |
# |    ep_rew_mean      | 602      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3852     |
# |    fps              | 249      |
# |    time_elapsed     | 3943     |
# |    total_timesteps  | 984281   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0127   |
# |    n_updates        | 221070   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.04e+03 |
# |    ep_rew_mean      | 604      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3856     |
# |    fps              | 249      |
# |    time_elapsed     | 3948     |
# |    total_timesteps  | 985518   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0214   |
# |    n_updates        | 221379   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.04e+03 |
# |    ep_rew_mean      | 608      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3860     |
# |    fps              | 249      |
# |    time_elapsed     | 3956     |
# |    total_timesteps  | 987610   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0501   |
# |    n_updates        | 221902   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.07e+03 |
# |    ep_rew_mean      | 617      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3864     |
# |    fps              | 249      |
# |    time_elapsed     | 3963     |
# |    total_timesteps  | 989416   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0208   |
# |    n_updates        | 222353   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.08e+03 |
# |    ep_rew_mean      | 619      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3868     |
# |    fps              | 249      |
# |    time_elapsed     | 3968     |
# |    total_timesteps  | 990919   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0247   |
# |    n_updates        | 222729   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.09e+03 |
# |    ep_rew_mean      | 621      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3872     |
# |    fps              | 249      |
# |    time_elapsed     | 3973     |
# |    total_timesteps  | 991864   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0524   |
# |    n_updates        | 222965   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.07e+03 |
# |    ep_rew_mean      | 616      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3876     |
# |    fps              | 249      |
# |    time_elapsed     | 3981     |
# |    total_timesteps  | 994156   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0198   |
# |    n_updates        | 223538   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.06e+03 |
# |    ep_rew_mean      | 614      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3880     |
# |    fps              | 249      |
# |    time_elapsed     | 3987     |
# |    total_timesteps  | 995613   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0242   |
# |    n_updates        | 223903   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.06e+03 |
# |    ep_rew_mean      | 615      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3884     |
# |    fps              | 249      |
# |    time_elapsed     | 3992     |
# |    total_timesteps  | 997270   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0138   |
# |    n_updates        | 224317   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.06e+03 |
# |    ep_rew_mean      | 613      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3888     |
# |    fps              | 249      |
# |    time_elapsed     | 3997     |
# |    total_timesteps  | 998524   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0232   |
# |    n_updates        | 224630   |
# ----------------------------------
# Eval num_timesteps=1000000, episode_reward=533.00 +/- 196.76
# Episode length: 4257.00 +/- 1397.67
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 4.26e+03 |
# |    mean_reward      | 533      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 1000000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00751  |
# |    n_updates        | 224999   |
# ----------------------------------
# Saving to logs//dqn/SpaceInvadersNoFrameskip-v4_1

# %% [markdown]
# ## Let's evaluate our agent 👀

# %%
# !python -m rl_zoo3.enjoy  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --no-render  --n-timesteps 5000  --folder logs/
# Out:
# 2024-07-24 07:51:35.944429: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-24 07:51:35.944484: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-24 07:51:35.945902: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-24 07:51:35.953478: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-24 07:51:36.937053: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loading latest experiment, id=1
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_1/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# Stacking 4 frames
# Atari Episode Score: 1170.00
# Atari Episode Length 6358
# Atari Episode Score: 495.00
# Atari Episode Length 4269
# Atari Episode Score: 310.00
# Atari Episode Length 2945

# %%
# !python -m rl_zoo3.push_to_hub  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --repo-name dqn-SpaceInvadersNoFrameskip-v4  -orga alz1319  -f logs/
# Out:
# 2024-07-24 07:58:20.323505: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-24 07:58:20.323551: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-24 07:58:20.324865: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-24 07:58:20.331809: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-24 07:58:21.350877: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loading latest experiment, id=1
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_1/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Uploading to alz1319/dqn-SpaceInvadersNoFrameskip-v4, make sure to have the rights
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to some
# minutes if video generation is activated. This is a work in progress: if you
# encounter a bug, please open an issue.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'Repository' (from 'huggingface_hub.repository') is deprecated and will be removed from version '1.0'. Please prefer the http-based alternatives instead. Given its large adoption in legacy code, the complete removal is only planned on next major release.
# For more details, please read https://huggingface.co/docs/huggingface_hub/concepts/git_vs_http.
#   warnings.warn(warning_message, FutureWarning)
# Cloning https://huggingface.co/alz1319/dqn-SpaceInvadersNoFrameskip-v4 into local empty directory.
# WARNING:huggingface_hub.repository:Cloning https://huggingface.co/alz1319/dqn-SpaceInvadersNoFrameskip-v4 into local empty directory.
# Saving model to: hub/dqn-SpaceInvadersNoFrameskip-v4/dqn-SpaceInvadersNoFrameskip-v4
# /usr/local/lib/python3.10/dist-packages/gymnasium/utils/passive_env_checker.py:335: UserWarning: WARN: No render fps was declared in the environment (env.metadata['render_fps'] is None or not defined), rendering may occur at inconsistent fps.
#   logger.warn(
# Saving video to /tmp/tmp34tyrlqj/-step-0-to-step-1000.mp4
# Moviepy - Building video /tmp/tmp34tyrlqj/-step-0-to-step-1000.mp4.
# Moviepy - Writing video /tmp/tmp34tyrlqj/-step-0-to-step-1000.mp4
#
# Moviepy - Done !
# Moviepy - video ready /tmp/tmp34tyrlqj/-step-0-to-step-1000.mp4
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/tmp/tmp34tyrlqj/-step-0-to-step-1000.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:33.40, start: 0.000000, bitrate: 54 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 160x210, 52 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x597ff0c5dfc0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x597ff0c5dfc0] profile High, level 1.2, 4:2:0, 8-bit
# [libx264 @ 0x597ff0c5dfc0] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'hub/dqn-SpaceInvadersNoFrameskip-v4/replay.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 160x210, q=2-31, 30 fps, 15360 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame= 1002 fps=711 q=-1.0 Lsize=     218kB time=00:00:33.30 bitrate=  53.7kbits/s speed=23.6x
# video:207kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 5.146287%
# [libx264 @ 0x597ff0c5dfc0] frame I:5     Avg QP:17.33  size:  3423
# [libx264 @ 0x597ff0c5dfc0] frame P:513   Avg QP:22.57  size:   329
# [libx264 @ 0x597ff0c5dfc0] frame B:484   Avg QP:30.30  size:    54
# [libx264 @ 0x597ff0c5dfc0] consecutive B-frames: 28.9% 16.6% 10.2% 44.3%
# [libx264 @ 0x597ff0c5dfc0] mb I  I16..4: 20.9% 37.3% 41.9%
# [libx264 @ 0x597ff0c5dfc0] mb P  I16..4:  0.6%  0.9%  0.9%  P16..4:  6.3%  2.8%  1.7%  0.0%  0.0%    skip:86.9%
# [libx264 @ 0x597ff0c5dfc0] mb B  I16..4:  0.2%  0.1%  0.1%  B16..8:  8.8%  0.9%  0.1%  direct: 0.2%  skip:89.6%  L0:49.9% L1:49.6% BI: 0.5%
# [libx264 @ 0x597ff0c5dfc0] 8x8 transform intra:37.1% inter:4.5%
# [libx264 @ 0x597ff0c5dfc0] coded y,uvDC,uvAC intra: 22.9% 39.8% 36.8% inter: 1.5% 1.8% 1.5%
# [libx264 @ 0x597ff0c5dfc0] i16 v,h,dc,p: 39% 55%  6%  0%
# [libx264 @ 0x597ff0c5dfc0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 25%  6% 68%  1%  0%  0%  0%  0%  0%
# [libx264 @ 0x597ff0c5dfc0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 32% 12% 43%  2%  2%  3%  2%  3%  2%
# [libx264 @ 0x597ff0c5dfc0] i8c dc,h,v,p: 52% 31% 16%  1%
# [libx264 @ 0x597ff0c5dfc0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x597ff0c5dfc0] ref P L0: 75.4%  6.2% 11.1%  7.4%
# [libx264 @ 0x597ff0c5dfc0] ref B L0: 83.5% 13.4%  3.1%
# [libx264 @ 0x597ff0c5dfc0] ref B L1: 96.4%  3.6%
# [libx264 @ 0x597ff0c5dfc0] kb/s:50.72
# ℹ Pushing repo dqn-SpaceInvadersNoFrameskip-v4 to the Hugging Face
# Hub
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip:   0% 1.00/26.0M [00:00<?, ?B/s]
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.pth:   0% 1.00/12.9M [00:00<?, ?B/s]
#
# Upload file train_eval_metrics.zip:   0% 1.00/35.4k [00:00<?, ?B/s]
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth:   0% 1.00/12.9M [00:00<?, ?B/s]
#
#
#
# Upload file replay.mp4:   0% 1.00/218k [00:00<?, ?B/s]
#
#
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip:  59% 15.3M/26.0M [00:01<00:00, 16.0MB/s]
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth: 15.3MB [00:01, 16.0MB/s]
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.pth: 15.3MB [00:01, 16.0MB/s]       To https://huggingface.co/alz1319/dqn-SpaceInvadersNoFrameskip-v4
#    4642006..27355ec  main -> main
#
# WARNING:huggingface_hub.repository:To https://huggingface.co/alz1319/dqn-SpaceInvadersNoFrameskip-v4
#    4642006..27355ec  main -> main
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip: 100% 26.0M/26.0M [00:03<00:00, 9.06MB/s]
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.pth: 100% 12.9M/12.9M [00:03<00:00, 4.49MB/s]
#
#
# Upload file train_eval_metrics.zip: 100% 35.4k/35.4k [00:03<00:00, 5.32MB/s]
#
# Upload file train_eval_metrics.zip: 100% 35.4k/35.4k [00:03<00:00, 12.0kB/s]
#
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth: 100% 12.9M/12.9M [00:03<00:00, 4.49MB/s]
#
#
#
#
# Upload file replay.mp4: 100% 218k/218k [00:03<00:00, 5.32MB/s]
#
#
#
# Upload file replay.mp4: 100% 218k/218k [00:03<00:00, 74.3kB/s]
#
#
#
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/pytorch_variables.pth: 100% 864/864 [00:03<00:00, 5.32MB/s]
#
#
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/pytorch_variables.pth: 100% 864/864 [00:03<00:00, 287B/s]
# ℹ Your model is pushed to the hub. You can view your model here:
# https://huggingface.co/alz1319/dqn-SpaceInvadersNoFrameskip-v4

# %% [markdown]
# ###.
